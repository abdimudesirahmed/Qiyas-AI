# %%
import pandas as pd
import numpy as np

#=======================================
#Hospital Patient Registration Cleaning
#=======================================

data = {
'Patient_ID':['P001','P002','P003','P004','P004'],
'Full_Name':['Abebe Kebede',' Hana Tesfaye ','Samuel Bekele',

'Meron Alemu','Meron Alemu'],

'Age':[35,np.nan,42,29,29],
'Address':[
'Bole Road, Addis Ababa, Bole, 03, H125',
'CMC Road, Addis Ababa, Yeka, 10, H201',
'Piassa, Addis Ababa, Arada, 01, H505',
'Megenagna, Addis Ababa, Bole, 05, H901',
'Megenagna, Addis Ababa, Bole, 05, H901'
]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)
print(df.isnull().sum())
df["age"] =df["Age"].fillna(df["Age"].mean(), inplace=True)
df = df.drop_duplicates()
df["Full_Name"] = df["Full_Name"].str.strip()
df[["First_Name", "Last_Name"]] = df["Full_Name"].str.split(" ", expand=True)
df[["Street", "City", "Subcity", "Woreda", "House_No"]] = df["Address"].str.split(", ", expand=True)
print(df)
# Out:
# Original DataFrame:
#   Patient_ID       Full_Name   Age                                 Address
# 0       P001    Abebe Kebede  35.0  Bole Road, Addis Ababa, Bole, 03, H125
# 1       P002   Hana Tesfaye    NaN   CMC Road, Addis Ababa, Yeka, 10, H201
# 2       P003   Samuel Bekele  42.0    Piassa, Addis Ababa, Arada, 01, H505
# 3       P004     Meron Alemu  29.0  Megenagna, Addis Ababa, Bole, 05, H901
# 4       P004     Meron Alemu  29.0  Megenagna, Addis Ababa, Bole, 05, H901
# Patient_ID    0
# Full_Name     0
# Age           1
# Address       0
# dtype: int64
#   Patient_ID      Full_Name   Age                                 Address  \
# 0       P001   Abebe Kebede  35.0  Bole Road, Addis Ababa, Bole, 03, H125
# 1       P002   Hana Tesfaye   NaN   CMC Road, Addis Ababa, Yeka, 10, H201
# 2       P003  Samuel Bekele  42.0    Piassa, Addis Ababa, Arada, 01, H505
# 3       P004    Meron Alemu  29.0  Megenagna, Addis Ababa, Bole, 05, H901
#
#      age First_Name Last_Name     Street         City Subcity Woreda House_No
# 0  35.00      Abebe    Kebede  Bole Road  Addis Ababa    Bole     03     H125
# 1  33.75       Hana   Tesfaye   CMC Road  Addis Ababa    Yeka     10     H201
# 2  42.00     Samuel    Bekele     Piassa  Addis Ababa   Arada     01     H505
# 3  29.00      Meron     Alemu  Megenagna  Addis Ababa    Bole     05     H901
# C:\Users\j\AppData\Local\Temp\ipykernel_3236\3111729688.py:29: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["age"] =df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
#=================================
#Online Store Sales Report
#=================================

data = {
'Month':['Jan','Jan','Feb','Feb','Mar','Mar'],
'Product':['Laptop','Phone','Laptop','Phone','Laptop','Phone'],
'Sales':[15,np.nan,18,20,15,25]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
print(df.isnull().sum())
print(df.fillna(0))
total_sales = df["Sales"].sum()
print(f"Total Sales: {total_sales}")

pivat_table = df.pivot_table(
    index='Month',
    columns='Product',
    values='Sales',
)
pivat_table = pivat_table.fillna(0)
print(pivat_table)
# Out:
# Original DataFrame:
#   Month Product  Sales
# 0   Jan  Laptop   15.0
# 1   Jan   Phone    NaN
# 2   Feb  Laptop   18.0
# 3   Feb   Phone   20.0
# 4   Mar  Laptop   15.0
# 5   Mar   Phone   25.0
# Month      0
# Product    0
# Sales      1
# dtype: int64
#   Month Product  Sales
# 0   Jan  Laptop   15.0
# 1   Jan   Phone    0.0
# 2   Feb  Laptop   18.0
# 3   Feb   Phone   20.0
# 4   Mar  Laptop   15.0
# 5   Mar   Phone   25.0
# Total Sales: 93.0
# Product  Laptop  Phone
# Month
# Feb        18.0   20.0
# Jan        15.0    0.0
# Mar        15.0   25.0

# %%
#=================================
#Employee Email Processing
#=================================

data = {
'Employee_ID':['E1','E2','E3','E4'],
'Email':[
'abebe@gmail.com',
'hana@yahoo.com',
'samuel@outlook.com',
'meron@gmail.com'
]
}

df = pd.DataFrame(data)
df[["Username","Domain"]] = df["Email"].str.split("@", expand=True)
df["Company_Email"] = df["Username"] + "@company.com"
print(df)
print(df["Domain"].value_counts("gmail.com"))
# Out:
#   Employee_ID               Email Username       Domain       Company_Email
# 0          E1     abebe@gmail.com    abebe    gmail.com   abebe@company.com
# 1          E2      hana@yahoo.com     hana    yahoo.com    hana@company.com
# 2          E3  samuel@outlook.com   samuel  outlook.com  samuel@company.com
# 3          E4     meron@gmail.com    meron    gmail.com   meron@company.com
# Domain
# gmail.com      2
# yahoo.com      1
# outlook.com    1
# Name: count, dtype: int64
